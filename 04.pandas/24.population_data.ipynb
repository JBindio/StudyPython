# %% [markdown]
# ### 인구 공공데이터

# %%
import pandas as pd

# %%
df = pd.read_csv('./data/people_202101.csv',encoding='cp949')
df
# Out:
#                               행정구역 2021년01월_계_총인구수 2021년01월_계_연령구간인구수  \
# 0              서울특별시  (1100000000)       9,657,969          9,657,969
# 1           서울특별시 종로구 (1111000000)         149,125            149,125
# 2      서울특별시 종로구 청운효자동(1111051500)          12,426             12,426
# 3        서울특별시 종로구 사직동(1111053000)           9,544              9,544
# 4        서울특별시 종로구 삼청동(1111054000)           2,613              2,613
# ...                            ...             ...                ...
# 3841  제주특별자치도 서귀포시 서홍동(5013058000)          10,743             10,743
# 3842  제주특별자치도 서귀포시 대륜동(5013059000)          14,826             14,826
# 3843  제주특별자치도 서귀포시 대천동(5013060000)          13,900             13,900
# 3844  제주특별자치도 서귀포시 중문동(5013061000)          11,543             11,543
# 3845  제주특별자치도 서귀포시 예래동(5013062000)           3,934              3,934
#
#      2021년01월_계_0세 2021년01월_계_1세 2021년01월_계_2세 2021년01월_계_3세 2021년01월_계_4세  \
# ...

# %%
# 서울특별시 관악구 신림동(1162069500) 정보 확인
df2 = df[df['행정구역'] == '서울특별시 관악구 신림동(1162069500)']
df2
# Out:
#                           행정구역 2021년01월_계_총인구수 2021년01월_계_연령구간인구수  \
# 355  서울특별시 관악구 신림동(1162069500)          21,831             21,831
#
#     2021년01월_계_0세 2021년01월_계_1세 2021년01월_계_2세 2021년01월_계_3세 2021년01월_계_4세  \
# 355            42            43            29            47            39
#
#     2021년01월_계_5세 2021년01월_계_6세  ... 2021년01월_계_92세 2021년01월_계_93세  \
# 355            37            40  ...              8              6
#
#     2021년01월_계_94세 2021년01월_계_95세 2021년01월_계_96세 2021년01월_계_97세  \
# 355              5              3              1              1
#
#     2021년01월_계_98세 2021년01월_계_99세 2021년01월_계_100세 이상  행정구역시
# 355              1              3                 16  서울특별시
#
# [1 rows x 105 columns]

# %%
df['행정구역시'] = df['행정구역'].apply(lambda x : x.split(' ')[0])
df[df['행정구역시'] == '부산광역시']
# Out:
#                           행정구역 2021년01월_계_총인구수 2021년01월_계_연령구간인구수  \
# 451        부산광역시  (2600000000)       3,389,388          3,389,388
# 452      부산광역시 중구 (2611000000)          41,549             41,549
# 453   부산광역시 중구 중앙동(2611051000)           2,518              2,518
# 454   부산광역시 중구 동광동(2611052000)           2,888              2,888
# 455   부산광역시 중구 대청동(2611053000)           6,505              6,505
# ..                         ...             ...                ...
# 668  부산광역시 기장군 기장읍(2671025000)          53,060             53,060
# 669  부산광역시 기장군 장안읍(2671025300)           8,663              8,663
# 670  부산광역시 기장군 정관읍(2671025600)          81,877             81,877
# 671  부산광역시 기장군 일광면(2671031000)          23,776             23,776
# 672  부산광역시 기장군 철마면(2671033000)           8,052              8,052
#
#     2021년01월_계_0세 2021년01월_계_1세 2021년01월_계_2세 2021년01월_계_3세 2021년01월_계_4세  \
# 451        14,305        17,113        19,108        21,366        24,298
# ...

# %%
df2 = df2.drop(
    ['행정구역', '2021년01월_계_총인구수', '2021년01월_계_연령구간인구수'], axis=1)
df2.head()
# Out:
#     2021년01월_계_0세 2021년01월_계_1세 2021년01월_계_2세 2021년01월_계_3세 2021년01월_계_4세  \
# 355            42            43            29            47            39
#
#     2021년01월_계_5세 2021년01월_계_6세 2021년01월_계_7세 2021년01월_계_8세 2021년01월_계_9세  \
# 355            37            40            21            29            32
#
#      ... 2021년01월_계_92세 2021년01월_계_93세 2021년01월_계_94세 2021년01월_계_95세  \
# 355  ...              8              6              5              3
#
#     2021년01월_계_96세 2021년01월_계_97세 2021년01월_계_98세 2021년01월_계_99세  \
# 355              1              1              1              3
#
#     2021년01월_계_100세 이상  행정구역시
# 355                 16  서울특별시
#
# [1 rows x 102 columns]

# %%
df3 = df2.melt()
df3.drop('variable', axis=1, inplace=True)
df3
# Out:
#      value
# 0       42
# 1       43
# 2       29
# 3       47
# 4       39
# ..     ...
# 97       1
# 98       1
# 99       3
# 100     16
# 101  서울특별시
#
# [102 rows x 1 columns]
