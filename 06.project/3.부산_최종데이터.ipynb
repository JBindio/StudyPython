# %% [markdown]
# ### 정제된 데이터 최종확인 및 합본 생성

# %%
import pandas as pd

# %%
busan_charge_all = pd.read_csv('./data/newdata/2. 충전소/부산_충전소_이용제한없음_최종.csv')
busan_charge_else = pd.read_csv('./data/newdata/2. 충전소/부산_충전소_이용제한있음_최종.csv')

# %%
busan_charge_all.info()
busan_charge_all.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   운영기관    1512 non-null   object
#  1   충전소     1512 non-null   object
#  2   충전기ID   1512 non-null   int64
#  3   충전기타입   1512 non-null   object
#  4   지역      1512 non-null   object
#  5   시군구     1512 non-null   object
#  6   주소      1512 non-null   object
#  7   이용자 제한  1512 non-null   object
#  8   위도      1512 non-null   float64
#  9   경도      1512 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 118.2+ KB
#              충전기ID           위도           경도
# count  1512.000000  1512.000000  1512.000000
# mean      3.565476    35.171203   129.063217
# std       7.019851     0.056320     0.082599
# min       1.000000    35.050461   128.825945
# 25%       1.000000    35.137711   129.012319
# 50%       2.000000    35.168031   129.067233
# ...

# %%
busan_charge_all[busan_charge_all.duplicated()]
# Out:
# Empty DataFrame
# Columns: [운영기관, 충전소, 충전기ID, 충전기타입, 지역, 시군구, 주소, 이용자 제한, 위도, 경도]
# Index: []

# %%
busan_charge_else.info()
busan_charge_else.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4796 entries, 0 to 4795
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   운영기관    4796 non-null   object
#  1   충전소     4796 non-null   object
#  2   충전기ID   4796 non-null   int64
#  3   충전기타입   4796 non-null   object
#  4   지역      4796 non-null   object
#  5   시군구     4796 non-null   object
#  6   주소      4796 non-null   object
#  7   이용자 제한  4796 non-null   object
#  8   위도      4796 non-null   float64
#  9   경도      4796 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 374.8+ KB
#              충전기ID           위도           경도
# count  4796.000000  4796.000000  4796.000000
# mean      4.450375    35.169575   129.078028
# std       4.915579     0.057490     0.077578
# min       1.000000    35.043198   128.809604
# 25%       2.000000    35.133979   129.030184
# 50%       3.000000    35.165396   129.084247
# ...

# %%
# 중복치 확인
busan_charge_else[busan_charge_else.duplicated()]
# Out:
#       운영기관           충전소  충전기ID 충전기타입     지역  시군구                주소  \
# 2238  파워큐브  경보아파트입주자대표회의      1  AC완속  부산광역시  금정구  부산광역시 금정구 금단로 33
# 2240  파워큐브  경보아파트입주자대표회의      2  AC완속  부산광역시  금정구  부산광역시 금정구 금단로 33
#
#          이용자 제한         위도          경도
# 2238  거주자외 출입제한  35.252569  129.092847
# 2240  거주자외 출입제한  35.252569  129.092847

# %%
# 중복치 제거
busan_charge_else = busan_charge_else.drop_duplicates().reset_index(drop=True)
busan_charge_else
# Out:
#             운영기관                              충전소  충전기ID            충전기타입  \
# 0         파킹클라우드                        부산 동트레아파트      1             AC완속
# 1         파킹클라우드                        부산 동트레아파트      2             AC완속
# 2     제주전기자동차서비스                   경보이리스오션더스타2차B1      1  DC차데모+AC3상+DC콤보
# 3     제주전기자동차서비스  금정산SKTVIEW 아파트 101동 A주차장 62번 기둥      1             AC완속
# 4     제주전기자동차서비스  금정산SKTVIEW 아파트 102동 A주차장 29번 기둥      1             AC완속
# ...          ...                              ...    ...              ...
# 4789      한국전자금융                     롯데월드 어드벤처 부산      4             AC완속
# 4790      한국전자금융                     롯데월드 어드벤처 부산      5             AC완속
# 4791      한국전자금융                     롯데월드 어드벤처 부산      6             AC완속
# 4792      한국전자금융                     롯데월드 어드벤처 부산      7             AC완속
# 4793      한국전자금융                     롯데월드 어드벤처 부산      8       DC차데모+DC콤보
#
#          지역  시군구                                   주소                  이용자 제한  \
# ...

# %%
busan_charge = pd.concat([busan_charge_all,busan_charge_else]).reset_index(drop=True)
busan_charge
# Out:
#                 운영기관           충전소  충전기ID            충전기타입     지역  시군구  \
# 0     환경부(한국자동차환경협회)    kbs 부산방송총국      1  DC차데모+AC3상+DC콤보  부산광역시  수영구
# 1     환경부(한국자동차환경협회)    kbs 부산방송총국     11             DC콤보  부산광역시  수영구
# 2     환경부(한국자동차환경협회)    kbs 부산방송총국     12             DC콤보  부산광역시  수영구
# 3     환경부(한국자동차환경협회)       국립부산과학관     11             DC콤보  부산광역시  기장군
# 4     환경부(한국자동차환경협회)       국립부산과학관     12             DC콤보  부산광역시  기장군
# ...              ...           ...    ...              ...    ...  ...
# 6301          한국전자금융  롯데월드 어드벤처 부산      4             AC완속  부산광역시  기장군
# 6302          한국전자금융  롯데월드 어드벤처 부산      5             AC완속  부산광역시  기장군
# 6303          한국전자금융  롯데월드 어드벤처 부산      6             AC완속  부산광역시  기장군
# 6304          한국전자금융  롯데월드 어드벤처 부산      7             AC완속  부산광역시  기장군
# 6305          한국전자금융  롯데월드 어드벤처 부산      8       DC차데모+DC콤보  부산광역시  기장군
#
#                                        주소                  이용자 제한         위도  \
# ...

# %%
busan_charge_all.to_csv('./data/newdata/2. 충전소/부산_충전소_이용제한없음_최종.csv',index=False)
busan_charge_else.to_csv('./data/newdata/2. 충전소/부산_충전소_이용제한있음_최종.csv',index=False)
busan_charge.to_csv('./data/newdata/2. 충전소/부산_충전소_전체_최종.csv',index=False)
