# %%
import pandas as pd
import numpy as np
import folium
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc
import seaborn as sns
import platform
import glob

# %%
# seaborn 설정 리셋
sns.reset_defaults()

# 폰트설정
if platform.system() == 'Windows' :
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
else :
    print('Check your OS System')
    
# 그래프에 마이너스 표시
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame()

read = glob.glob('./data/rawdata/주유소/*_주유소_현황.csv')
for i in read:
        data = pd.read_csv(i,encoding='euc-kr')
        df = pd.concat([df, data],ignore_index= True)
df
# Out:
#       연번                    상호  \
# 0    1.0    ㈜지원네트웍스 부산강서LPG충전소
# 1    2.0                 가락충전소
# 2    3.0        개인택시 신공항LPG충전소
# 3    4.0              르노삼성자동차㈜
# 4    5.0            부산공항LPG충전소
# ..   ...                   ...
# 228  NaN          대양산업(주)동화주유소
# 229  NaN        (주)OS에너지 해변주유소
# 230  NaN                 백천주유소
# 231  NaN  현대오일뱅크(주) 직영 센텀셀프주유소
# 232  NaN       SK에너지(주)송정셀프주유소
#
#                                                    소재지          전화번호    사업종류  \
# 0                                             낙동북로 310  051-972-0245  LPG충전소
# 1                                              호계로 195  051-971-3430  LPG충전소
# 2                                         경전철로188번길 95  051-941-3485  LPG충전소
# 3                                            르노삼성대로 61  051-979-9085  LPG충전소
# 4                                              공항로 459  051-973-4036  LPG충전소
# ..                                                 ...           ...     ...
# 228                          부산광역시 해운대구 해운대해변로 44 (우동)           NaN     NaN
# 229                           부산광역시 해운대구 해운대로 345 (우동)           NaN     NaN
# 230  부산광역시 해운대구 해운대로 211 (재송동,외4필지(652-6,652-8,660-...           NaN     NaN
# 231                    부산광역시 해운대구 해운대로 592, 해변주유소 (우동)           NaN     NaN
# 232                           부산광역시 해운대구 반송로 910 (반송동)           NaN     NaN
#
#      순번   주소 사업구분 영업소소재지(도로명) 영업소소재지(지번)  상호명 도로명주소 데이터기준일자 대표자이름 영업소 소재지  \
# 0   NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 1   NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 2   NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 3   NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 4   NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# ..   ..  ...  ...         ...        ...  ...   ...     ...   ...     ...
# 228 NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 229 NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 230 NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 231 NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
# 232 NaN  NaN  NaN         NaN        NaN  NaN   NaN     NaN   NaN     NaN
#
#        번호           연락처   구분
# 0     NaN           NaN  NaN
# 1     NaN           NaN  NaN
# 2     NaN           NaN  NaN
# 3     NaN           NaN  NaN
# 4     NaN           NaN  NaN
# ..    ...           ...  ...
# 228  33.0  051-781-4400  주유소
# 229  34.0  051-747-7780  주유소
# 230  35.0  051 542 7979  주유소
# 231  36.0  051-784-0293  주유소
# 232  37.0  051-704-0011  주유소
#
# [233 rows x 18 columns]

# %%
df['주소'].value_counts()
# Out:
# 기장읍 서부리 429          1
# 일광면 삼성리 25           1
# 장안읍 명례리 779-8        1
# 기장읍 청강리 12           1
# 기장읍 내리 307-8         1
#                     ..
# 정관읍 예림리 1018-1       1
# 정관읍 예림리 1020-1       1
# 장안읍 좌동리 278          1
# 정관읍 예림리 851          1
# 부산광역시 북구 금곡대로 203    1
# Name: 주소, Length: 64, dtype: int64
