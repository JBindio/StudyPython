# %%
import pandas as pd

# %%
df = pd.read_csv('./data/people_202101.csv', encoding='cp949', thousands=',')
df.head()
# Out:
#                           행정구역  2021년01월_계_총인구수  2021년01월_계_연령구간인구수  \
# 0          서울특별시  (1100000000)          9657969             9657969
# 1       서울특별시 종로구 (1111000000)           149125              149125
# 2  서울특별시 종로구 청운효자동(1111051500)            12426               12426
# 3    서울특별시 종로구 사직동(1111053000)             9544                9544
# 4    서울특별시 종로구 삼청동(1111054000)             2613                2613
#
#    2021년01월_계_0세  2021년01월_계_1세  2021년01월_계_2세  2021년01월_계_3세  2021년01월_계_4세  \
# 0          44249          49910          52741          56732          63560
# 1            464            588            564            663            761
# 2             47             60             65             77             71
# 3             27             37             33             54             69
# 4              7              7              6             16              3
#
#    2021년01월_계_5세  2021년01월_계_6세  ...  2021년01월_계_91세  2021년01월_계_92세  \
# ...

# %%
df['행정구역 시'] = df['행정구역'].apply(lambda x : x.split(' ')[0])
df['행정구역 구'] = df['행정구역'].apply(lambda x : x.split(' ')[1])
df['행정구역 동'] = df['행정구역'].apply(lambda x : x.split(' ')[2])
df.head()

df[df['행정구역 시'] == '부산광역시']
# Out:
#                           행정구역  2021년01월_계_총인구수  2021년01월_계_연령구간인구수  \
# 451        부산광역시  (2600000000)          3389388             3389388
# 452      부산광역시 중구 (2611000000)            41549               41549
# 453   부산광역시 중구 중앙동(2611051000)             2518                2518
# 454   부산광역시 중구 동광동(2611052000)             2888                2888
# 455   부산광역시 중구 대청동(2611053000)             6505                6505
# ..                         ...              ...                 ...
# 668  부산광역시 기장군 기장읍(2671025000)            53060               53060
# 669  부산광역시 기장군 장안읍(2671025300)             8663                8663
# 670  부산광역시 기장군 정관읍(2671025600)            81877               81877
# 671  부산광역시 기장군 일광면(2671031000)            23776               23776
# 672  부산광역시 기장군 철마면(2671033000)             8052                8052
#
#      2021년01월_계_0세  2021년01월_계_1세  2021년01월_계_2세  2021년01월_계_3세  \
# 451          14305          17113          19108          21366
# ...

# %%
df.columns
# Out:
# Index(['행정구역', '2021년01월_계_총인구수', '2021년01월_계_연령구간인구수', '2021년01월_계_0세',
#        '2021년01월_계_1세', '2021년01월_계_2세', '2021년01월_계_3세', '2021년01월_계_4세',
#        '2021년01월_계_5세', '2021년01월_계_6세',
#        ...
#        '2021년01월_계_94세', '2021년01월_계_95세', '2021년01월_계_96세', '2021년01월_계_97세',
#        '2021년01월_계_98세', '2021년01월_계_99세', '2021년01월_계_100세 이상', '행정구역 시',
#        '행정구역 구', '행정구역 동'],
#       dtype='object', length=107)

# %%
df2 = df[df['행정구역'] == '서울특별시 관악구 신림동(1162069500)']
df2
# Out:
#                           행정구역  2021년01월_계_총인구수  2021년01월_계_연령구간인구수  \
# 355  서울특별시 관악구 신림동(1162069500)            21831               21831
#
#      2021년01월_계_0세  2021년01월_계_1세  2021년01월_계_2세  2021년01월_계_3세  \
# 355             42             43             29             47
#
#      2021년01월_계_4세  2021년01월_계_5세  2021년01월_계_6세  ...  2021년01월_계_94세  \
# 355             39             37             40  ...               5
#
#      2021년01월_계_95세  2021년01월_계_96세  2021년01월_계_97세  2021년01월_계_98세  \
# 355               3               1               1               1
#
#      2021년01월_계_99세  2021년01월_계_100세 이상  행정구역 시  행정구역 구           행정구역 동
# 355               3                  16   서울특별시     관악구  신림동(1162069500)
#
# [1 rows x 107 columns]

# %%
df2.drop(['행정구역', '2021년01월_계_총인구수', '2021년01월_계_연령구간인구수',
          '행정구역 시','행정구역 구', '행정구역 동'],axis=1, inplace= True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14116\3280238503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(['행정구역', '2021년01월_계_총인구수', '2021년01월_계_연령구간인구수',

# %%
df2
# Out:
#      2021년01월_계_0세  2021년01월_계_1세  2021년01월_계_2세  2021년01월_계_3세  \
# 355             42             43             29             47
#
#      2021년01월_계_4세  2021년01월_계_5세  2021년01월_계_6세  2021년01월_계_7세  \
# 355             39             37             40             21
#
#      2021년01월_계_8세  2021년01월_계_9세  ...  2021년01월_계_91세  2021년01월_계_92세  \
# 355             29             32  ...              10               8
#
#      2021년01월_계_93세  2021년01월_계_94세  2021년01월_계_95세  2021년01월_계_96세  \
# 355               6               5               3               1
#
#      2021년01월_계_97세  2021년01월_계_98세  2021년01월_계_99세  2021년01월_계_100세 이상
# 355               1               1               3                  16
#
# [1 rows x 101 columns]

# %%
df3 = df2.melt()
df3.drop('variable', axis=1, inplace=True)
df3
# Out:
#      value
# 0       42
# 1       43
# 2       29
# 3       47
# 4       39
# ..     ...
# 96       1
# 97       1
# 98       1
# 99       3
# 100     16
#
# [101 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(range(101), df4['value'])
plt.show()

# %%
pdf = pd.read_csv('./data/people_gender_202101.csv', encoding='cp949', thousands=',')
pdf.head()
# Out:
#                           행정구역  2021년01월_남_총인구수  2021년01월_남_연령구간인구수  \
# 0          서울특별시  (1100000000)          4695999             4695999
# 1       서울특별시 종로구 (1111000000)            72528               72528
# 2  서울특별시 종로구 청운효자동(1111051500)             5784                5784
# 3    서울특별시 종로구 사직동(1111053000)             4273                4273
# 4    서울특별시 종로구 삼청동(1111054000)             1251                1251
#
#    2021년01월_남_0~9세  2021년01월_남_10~19세  2021년01월_남_20~29세  2021년01월_남_30~39세  \
# 0           317563             399754             704862             735813
# 1             3767               5443              11493               9883
# 2              430                618                795                772
# 3              290                306                568                619
# 4               47                108                164                170
#
#    2021년01월_남_40~49세  2021년01월_남_50~59세  2021년01월_남_60~69세  ...  \
# ...

# %%
pdf2 = pdf[pdf['행정구역'] == '서울특별시 관악구 신림동(1162069500)']
pdf2
# Out:
#                           행정구역  2021년01월_남_총인구수  2021년01월_남_연령구간인구수  \
# 355  서울특별시 관악구 신림동(1162069500)            11398               11398
#
#      2021년01월_남_0~9세  2021년01월_남_10~19세  2021년01월_남_20~29세  2021년01월_남_30~39세  \
# 355              178                231               4032               3247
#
#      2021년01월_남_40~49세  2021년01월_남_50~59세  2021년01월_남_60~69세  ...  \
# 355               1425                999                695  ...
#
#      2021년01월_여_10~19세  2021년01월_여_20~29세  2021년01월_여_30~39세  \
# 355                243               4304               2378
#
#      2021년01월_여_40~49세  2021년01월_여_50~59세  2021년01월_여_60~69세  \
# 355               1066                773                767
#
#      2021년01월_여_70~79세  2021년01월_여_80~89세  2021년01월_여_90~99세  \
# 355                497                173                 36
#
#      2021년01월_여_100세 이상
# 355                  15
#
# [1 rows x 27 columns]

# %%
pdf2.drop(['행정구역', '2021년01월_남_총인구수', '2021년01월_여_총인구수', 
           '2021년01월_남_연령구간인구수','2021년01월_여_연령구간인구수'],axis=1, inplace= True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14116\2268210748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdf2.drop(['행정구역', '2021년01월_남_총인구수', '2021년01월_여_총인구수',

# %%
pdf2
# Out:
#      2021년01월_남_0~9세  2021년01월_남_10~19세  2021년01월_남_20~29세  2021년01월_남_30~39세  \
# 355              178                231               4032               3247
#
#      2021년01월_남_40~49세  2021년01월_남_50~59세  2021년01월_남_60~69세  \
# 355               1425                999                695
#
#      2021년01월_남_70~79세  2021년01월_남_80~89세  2021년01월_남_90~99세  ...  \
# 355                443                138                  9  ...
#
#      2021년01월_여_10~19세  2021년01월_여_20~29세  2021년01월_여_30~39세  \
# 355                243               4304               2378
#
#      2021년01월_여_40~49세  2021년01월_여_50~59세  2021년01월_여_60~69세  \
# 355               1066                773                767
#
#      2021년01월_여_70~79세  2021년01월_여_80~89세  2021년01월_여_90~99세  \
# 355                497                173                 36
#
#      2021년01월_여_100세 이상
# 355                  15
#
# [1 rows x 22 columns]

# %%
male = pdf2.iloc[:, 0:11]
male
# Out:
#      2021년01월_남_0~9세  2021년01월_남_10~19세  2021년01월_남_20~29세  2021년01월_남_30~39세  \
# 355              178                231               4032               3247
#
#      2021년01월_남_40~49세  2021년01월_남_50~59세  2021년01월_남_60~69세  \
# 355               1425                999                695
#
#      2021년01월_남_70~79세  2021년01월_남_80~89세  2021년01월_남_90~99세  \
# 355                443                138                  9
#
#      2021년01월_남_100세 이상
# 355                   1

# %%
female = pdf2.iloc[:, 11:22]
female
# Out:
#      2021년01월_여_0~9세  2021년01월_여_10~19세  2021년01월_여_20~29세  2021년01월_여_30~39세  \
# 355              181                243               4304               2378
#
#      2021년01월_여_40~49세  2021년01월_여_50~59세  2021년01월_여_60~69세  \
# 355               1066                773                767
#
#      2021년01월_여_70~79세  2021년01월_여_80~89세  2021년01월_여_90~99세  \
# 355                497                173                 36
#
#      2021년01월_여_100세 이상
# 355                  15

# %%
male2 = male.melt()
male2.drop('variable', axis=1, inplace= True)
male2['value'] = male2['value'].apply(lambda x : x * -1)
male2
# Out:
#     value
# 0    -178
# 1    -231
# 2   -4032
# 3   -3247
# 4   -1425
# 5    -999
# 6    -695
# 7    -443
# 8    -138
# 9      -9
# 10     -1

# %%
female2 = female.melt()
female2.drop('variable', axis=1, inplace= True)
female2
# Out:
#     value
# 0     181
# 1     243
# 2    4304
# 3    2378
# 4    1066
# 5     773
# 6     767
# 7     497
# 8     173
# 9      36
# 10     15

# %%
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

plt.title('서울 신림동 남녀 성별 인구 분포')
plt.barh(range(11), male2['value'].tolist(), label ='남자')
plt.barh(range(11), female2['value'].tolist(), label ='여자')
plt.yticks(
    range(11),
    ['0,9', '10-19', '20-29', '30-39', '40-49','50,59', '60-69', '70-79', '80-89', '90-99', '100이상'])
plt.xlim(-4500, 4500)
plt.xticks(range(-4000, 4001, 2000),
['4000명', '2000명','0명','2000명','4000명'])
plt.legend()
plt.show()
